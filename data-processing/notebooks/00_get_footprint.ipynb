# %% [markdown]
# # Create footprint for the HBL area
# This notebook creates a footprint for the HBL area using one of the regional rasters. This footprint will be used to clip national or global rasters to the area of interest.

# %%
import sys

sys.path.append("../src/data_processing/")
from utils import raster_to_footprint

# %%
raster_to_footprint(
    raster_path="../data/processed/cogs/HBL_EcosystemClassification_cog.tif",
    output_vector="../data/processed/vectors/HBL_footprint.geojson",
)
