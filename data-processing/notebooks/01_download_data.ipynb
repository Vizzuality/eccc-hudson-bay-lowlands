# %% [markdown]
# # Data Download
#
# This notebook downloads the following vector and raster datasets for the ECCC platform:
#
# - [Dynamic Surface Water Maps of Canada from 1984-2023 Landsat Satellite Imagery](https://open.canada.ca/data/en/dataset/62de5952-a5eb-4859-b086-22a8ba8024b8): Inundation Frequency 1984-2023 and Inundation Trends 1984-2023
# - [Treed Area in Canada (1984–2022)](https://opendata.nfis.org/mapserver/nfis-change_eng.html)
# - [Flood Susceptibility Index](https://app.geo.ca/en-ca/map-browser/record/df106e11-4cee-425d-bd38-7e51ac674128)
# - [Annual 30 m snow dynamics (2018-2019 to 2023-2024)](https://app.geo.ca/en-ca/map-browser/record/1ed7fdec-9a50-4fe9-aa16-78f9ee3f05bc)
# - [National Ecological Framework for Canada](https://sis.agr.gc.ca/cansis/nsdb/ecostrat/index.html): Ecozones, Ecoprovinces, Ecoregions, Ecodistricts
# - [Mining Claims](https://www.geologyontario.mndm.gov.on.ca/ogsearth.html): Operational data
#
# Other datasets included in the platform that can't be downloaded using a script are:
#
# - Ecosystems Classification: Currenly under review and shared by email.
# - [Peat depth and carbon storage of the Hudson Bay Lowlands, Canada](https://borealisdata.ca/dataset.xhtml?persistentId=doi:10.5683/SP3/TIRAXJ): Borealis provides temporary links that can't be integrated in a script.
#
#
# ### Setup

# %%
import sys

# Add the src directory to Python path
sys.path.append('../src')

from data_processing.download import download_dataset

# %% [markdown]
# ### Download Datasets

# %%
# # Dynamic surface water: inundation frequency and inundation trend
# download_dataset("dynamic_surface_water", "../data/raw/rasters/CAN_dynamic_surface_water")

# # Tree cover
# download_dataset("tree_cover", "../data/raw/rasters/CAN_treed_area_1984-2022")

# # Flood index
# download_dataset("flood_index", "../data/raw/rasters/CAN_flood_susceptibility_index")

# # Snow dynamics
# download_dataset("snow_dynamics", "../data/raw/rasters/CAN_snow_dynamics")

# # Ecological framework vectors (ecozones, ecoprovinces, ecoregions, ecodistricts)
# download_dataset("ecological_framework", "../data/raw/vectors/", remove_zip=True)

# # Mining claims
# download_dataset("mining_claims", "../data/raw/vectors/", remove_zip=True)
